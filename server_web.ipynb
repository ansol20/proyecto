# %%
import http.server
import socketserver
import networkx as nx
import pandas as pd
import json
import base64

df = pd.read_json('hospitales_data_final.json')
cdf = pd.read_json('centroides_final.json')
maxima_distancia = 13

G=nx.Graph()
for index, row in df.iterrows():
    G.add_node(row["id"],pos=(row["cartesianas"][0],row["cartesianas"][1]))
    if row["distancia_centro"] !=0 :
        G.add_edge(row["hospitales_centros"],row["id"],weight=row["distancia_centro"])

for index, row in cdf.iterrows():
    if row["distancias"] < maxima_distancia:
        G.add_edge(row["inicio"],row["final"],weight=row["distancias"])

pos=nx.get_node_attributes(G,'pos')
nx.draw(G,pos)

PORT = 8000

class MyRequestHandler(http.server.SimpleHTTPRequestHandler):
    def do_GET(self):
        if self.path == '/':
            self.send_response(200)
            self.send_header('Content-Type', 'text/html')
            self.end_headers()
            fh=open('index.html','rb')
            string=fh.read()
            self.wfile.write(string)
        elif self.path.find('hospitales_data_final')>0:
            self.send_response(200)
            self.send_header('Content-Type', 'application/json')
            self.end_headers()
            fh=open('hospitales_data_final.json','rb')
            string=fh.read()
            self.wfile.write(string) 
        elif self.path.find('hospital42.png')>0:
            self.send_response(200)
            self.send_header('Content-Type', 'image/png')
            self.end_headers()
            fh=open('hospital42.png','rb')
            string=fh.read()
            self.wfile.write(string)     
        elif self.path.find('centroides_final')>0:
            self.send_response(200)
            self.send_header('Content-Type', 'application/json')
            self.end_headers()
            fh=open('centroides_final.json','rb')
            string=fh.read()
            self.wfile.write(string)               
        elif self.path.find('request_min_path')>0:
            self.send_response(200)
            self.send_header('Content-Type', 'application/json')
            self.end_headers()
            values = {}
            
            if '?' in self.path:
                data = self.path.split('?', 1)[1].split('&')
                for n in data:
                    d = n.split("=")
                    values[d[0]] = int(d[1])    
              
            data = {}
            if len(values.keys())>0 :
                data = {"ruta":nx.shortest_path(G, values["inicio"],values["final"])}
            json_object = json.dumps(data)  
            self.wfile.write(bytes(json_object, "utf8"))
        return 

Handler = MyRequestHandler
with socketserver.TCPServer(("", PORT), Handler) as httpd:
    print("serving at port", PORT)
    httpd.serve_forever()
# Out:
# serving at port 8000
# 186.101.146.61 - - [05/Jul/2021 16:32:41] "GET / HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 16:32:42] "GET / HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 16:32:42] "GET /hospitales_data_final HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 16:32:44] "GET /request_min_path?inicio=0&final=0 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 16:32:44] "GET /hospital42.png HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 16:54:56] "GET /hospitales_data_final HTTP/1.1" 200 -
# 185.53.90.90 - - [05/Jul/2021 17:34:39] code 400, message Bad HTTP/0.9 request type ('Z¥\x01')
# 185.53.90.90 - - [05/Jul/2021 17:34:39] "Z¥ " 400 -
# 186.101.146.61 - - [05/Jul/2021 17:40:18] "GET /hospitales_data_final HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:01:39] "GET /hospitales_data_final HTTP/1.1" 200 -
# 181.199.59.112 - - [05/Jul/2021 18:02:03] "GET / HTTP/1.1" 200 -
# 181.199.59.112 - - [05/Jul/2021 18:02:04] "GET /hospitales_data_final HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:02:09] "GET / HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:02:10] "GET /hospitales_data_final HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:02:18] "GET /request_min_path?inicio=0&final=1 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:02:18] "GET /hospital42.png HTTP/1.1" 200 -
# 181.199.59.112 - - [05/Jul/2021 18:02:41] "GET /request_min_path?inicio=1&final=8 HTTP/1.1" 200 -
# 181.199.59.112 - - [05/Jul/2021 18:02:41] "GET /hospital42.png HTTP/1.1" 200 -
# 181.199.59.112 - - [05/Jul/2021 18:04:02] "GET /request_min_path?inicio=3&final=8 HTTP/1.1" 200 -
# 181.199.59.112 - - [05/Jul/2021 18:04:07] "GET /request_min_path?inicio=3&final=23 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:48:45] "GET /request_min_path?inicio=0&final=2 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:48:57] "GET /request_min_path?inicio=0&final=3 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:49:01] "GET /request_min_path?inicio=0&final=4 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:49:14] "GET /request_min_path?inicio=0&final=5 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:49:14] "GET /request_min_path?inicio=0&final=4 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:49:16] "GET /request_min_path?inicio=0&final=5 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:49:19] "GET /request_min_path?inicio=0&final=5 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:49:23] "GET /request_min_path?inicio=0&final=6 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:49:28] "GET /request_min_path?inicio=0&final=7 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:49:32] "GET /request_min_path?inicio=0&final=7 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:49:35] "GET /request_min_path?inicio=0&final=8 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:49:40] "GET /request_min_path?inicio=0&final=9 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:49:47] "GET /request_min_path?inicio=0&final=10 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:49:56] "GET /hospitales_data_final HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:50:12] "GET /request_min_path?inicio=0&final=10 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:50:12] "GET /hospital42.png HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:50:22] "GET /request_min_path?inicio=0&final=11 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:50:24] "GET /request_min_path?inicio=0&final=11 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:50:27] "GET /request_min_path?inicio=0&final=12 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:50:38] "GET /request_min_path?inicio=0&final=13 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:50:44] "GET /request_min_path?inicio=0&final=14 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:50:49] "GET /request_min_path?inicio=0&final=15 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:50:54] "GET /request_min_path?inicio=0&final=16 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:51:10] "GET /request_min_path?inicio=0&final=16 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:51:14] "GET /request_min_path?inicio=0&final=17 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:51:35] "GET /request_min_path?inicio=0&final=18 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:51:41] "GET /request_min_path?inicio=0&final=19 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:51:52] "GET /request_min_path?inicio=0&final=20 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:52:15] "GET /request_min_path?inicio=0&final=21 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:52:20] "GET /request_min_path?inicio=0&final=22 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:52:22] "GET /request_min_path?inicio=0&final=17 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:52:24] "GET /request_min_path?inicio=0&final=23 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:52:28] "GET /request_min_path?inicio=0&final=24 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:52:35] "GET /request_min_path?inicio=0&final=25 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:52:41] "GET /request_min_path?inicio=0&final=26 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:52:47] "GET /request_min_path?inicio=0&final=27 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:52:52] "GET /request_min_path?inicio=0&final=28 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:53:00] "GET /request_min_path?inicio=0&final=28 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:53:33] "GET /request_min_path?inicio=0&final=28 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:53:39] "GET /request_min_path?inicio=0&final=28 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:53:44] "GET /request_min_path?inicio=0&final=29 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:53:56] "GET /request_min_path?inicio=0&final=30 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:54:15] "GET /request_min_path?inicio=0&final=30 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:54:25] "GET /request_min_path?inicio=0&final=31 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:54:59] "GET /request_min_path?inicio=0&final=31 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:55:10] "GET /request_min_path?inicio=0&final=30 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:56:15] "GET /request_min_path?inicio=0&final=30 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:56:18] "GET /request_min_path?inicio=0&final=31 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:56:28] "GET /request_min_path?inicio=0&final=31 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:56:48] "GET /request_min_path?inicio=0&final=31 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:57:34] "GET /request_min_path?inicio=0&final=30 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:57:54] "GET /request_min_path?inicio=0&final=31 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:58:26] "GET /request_min_path?inicio=0&final=30 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:58:31] "GET /request_min_path?inicio=0&final=32 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:58:36] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 103.145.13.121 - - [05/Jul/2021 18:59:30] code 400, message Bad HTTP/0.9 request type ('Z¥\x01')
# 103.145.13.121 - - [05/Jul/2021 18:59:30] "Z¥ " 400 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=34 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=30 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=30 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=30 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:30] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:59:30] "GET / HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:59:30] "GET /hospitales_data_final HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:32] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:32] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:32] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:32] "GET /request_min_path?inicio=0&final=34 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:32] "GET /request_min_path?inicio=0&final=34 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:33] "GET /request_min_path?inicio=0&final=34 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:33] "GET /request_min_path?inicio=0&final=34 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:33] "GET /request_min_path?inicio=0&final=34 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:33] "GET /request_min_path?inicio=0&final=34 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:33] "GET /request_min_path?inicio=0&final=34 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:59:41] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 18:59:41] "GET /hospital42.png HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 18:59:45] "GET /request_min_path?inicio=0&final=34 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:00:18] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:00:18] "GET / HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:00:18] "GET /hospitales_data_final HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:00:24] "GET /request_min_path?inicio=0&final=0 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:00:24] "GET /hospital42.png HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:00:24] "GET /request_min_path?inicio=0&final=0 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:00:24] "GET /request_min_path?inicio=0&final=0 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:00:27] "GET /request_min_path?inicio=0&final=5 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:00:30] "GET /request_min_path?inicio=0&final=32 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:00:35] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:00:36] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:00:55] "GET /request_min_path?inicio=0&final=30 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:01:09] "GET /request_min_path?inicio=0&final=33 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:01:25] "GET /request_min_path?inicio=0&final=34 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:03:24] "GET /request_min_path?inicio=0&final=34 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:03:41] "GET /request_min_path?inicio=0&final=30 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:03:52] "GET /request_min_path?inicio=0&final=35 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:03:56] "GET /request_min_path?inicio=0&final=36 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:04:03] "GET /request_min_path?inicio=0&final=37 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:05:15] "GET /request_min_path?inicio=0&final=37 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:05:19] "GET /request_min_path?inicio=0&final=38 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:05:25] "GET /request_min_path?inicio=0&final=39 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:05:31] "GET /request_min_path?inicio=0&final=40 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:05:42] "GET /request_min_path?inicio=0&final=40 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:05:48] "GET /request_min_path?inicio=0&final=40 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:05:48] "GET /request_min_path?inicio=0&final=40 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:05:48] "GET /request_min_path?inicio=0&final=40 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:05:49] "GET /request_min_path?inicio=0&final=41 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:06:05] "GET /request_min_path?inicio=0&final=42 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:06:05] "GET /request_min_path?inicio=0&final=42 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:06:22] "GET /request_min_path?inicio=0&final=43 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:06:39] "GET /request_min_path?inicio=0&final=44 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:06:45] "GET /request_min_path?inicio=0&final=45 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:06:52] "GET /request_min_path?inicio=0&final=46 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:07:03] "GET /request_min_path?inicio=0&final=47 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:07:29] "GET /request_min_path?inicio=0&final=48 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:08:57] "GET /request_min_path?inicio=0&final=49 HTTP/1.1" 200 -
# 186.101.146.61 - - [05/Jul/2021 19:09:14] "GET /request_min_path?inicio=0&final=49 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:13:45] "GET /request_min_path?inicio=0&final=49 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:13:49] "GET /request_min_path?inicio=0&final=50 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:14:00] "GET /request_min_path?inicio=0&final=51 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:15:00] "GET /request_min_path?inicio=0&final=52 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:15:06] "GET /request_min_path?inicio=0&final=53 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:16:01] "GET /request_min_path?inicio=0&final=53 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:17:44] "GET /request_min_path?inicio=1&final=0 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:18:37] "GET /request_min_path?inicio=1&final=1 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:18:49] "GET /request_min_path?inicio=1&final=2 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:19:43] "GET /request_min_path?inicio=1&final=46 HTTP/1.1" 200 -
# 186.69.75.226 - - [05/Jul/2021 19:21:51] "GET /request_min_path?inicio=1&final=53 HTTP/1.1" 200 -
# 103.145.13.121 - - [05/Jul/2021 20:30:23] code 400, message Bad HTTP/0.9 request type ('Z¥\x01')
# 103.145.13.121 - - [05/Jul/2021 20:30:23] "Z¥ " 400 -
